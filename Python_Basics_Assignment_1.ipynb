# %%
 #    Assignment no - 1
 #      write a program to find the version of python


import sys
print('python version')
print (sys.version)
print('version info')
print(sys.version_info)
help('modules')
# Out:
# python version
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# version info
# sys.version_info(major=3, minor=13, micro=9, releaselevel='final', serial=0)
#
# Please wait a moment while I gather a list of all available modules...
# C:\Users\dwive\anaconda3\Lib\site-packages\conda_pack\core.py:16: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# C:\Users\dwive\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning:
#
# The twython library has not been installed. Some functionality from the twitter package will not be available.
#
# C:\Users\dwive\anaconda3\Lib\pkgutil.py:78: UserWarning:
#
# The superqt.qtcompat module is deprecated as of v0.3.0. Please import from `qtpy` instead.
# ...

# %%
# 2- write a program to show date and time


import datetime
current_date_time = datetime.datetime.now() 
print('current&date_time')
print(current_date_time.strftime("%Y-%m-%d  %H:%M:%S"))
# Out:
# current&date_time
# 2026-06-01  19:40:07

# %%
# 3- write a program while accept the radius of circle from user and show area of circle 
from math import pi
r=float(input("entert the radius of circle")) 
area = pi*r*r
print('AREA OF CIRCLE=',area)
# Out:
# entert the radius of circle 7
# AREA OF CIRCLE= 153.93804002589985

# %%
# 4-write a program which accepts the user's first and last name and print them in reverse order and space between them
f_name=(input('enter the first name'))
l_name=(input('enter the last name'))
full_name= l_name +' '+f_name
print('welcome ',full_name)
# Out:
# enter the first name James
# enter the last name Bond
# welcome  Bond James

# %%
# 5- write a program to accept the number from users and seprate the with "," and  print them as a tuple and list
n=(input('enter the number with comma separated'))
list_1=n.split(',')
tuple_1=tuple(list_1)
print('list:',list_1)
print('tupple:',tuple_1)
# Out:
# enter the number with comma separated 9,0,8,6,5,9,2,3
# list: ['9', '0', '8', '6', '5', '9', '2', '3']
# tupple: ('9', '0', '8', '6', '5', '9', '2', '3')

# %%
#6- write a program to accept the file name from user and print the extension
file_name=(input('enter the file name with extn'))
f_extn=file_name.split(".")
print("file name"+repr(f_extn[-1]))
# Out:
# enter the file name with extn acamegrade.html
# file name'html'

# %%
#7- write a program to display first and last colour of following list
color_list=['red','green','black','yellow','blue']
print("%s %s",(color_list[0],color_list[-1]))
# Out:
# %s %s ('red', 'blue')

# %%
#8- write a program to accept the n integer the show the addition of n+nn+nnn
a=int(input('enter the integer'))
n1="%s"%(a)
n2="%d%d"%(a,a)
n3="%d%d%d"%(a,a,a)
print(int(n1)+int(n2)+int(n3))
# Out:
# enter the integer 9
# 1107

# %%
#9- write a program to find the volume of spare with radius 6
from math import pi
r=6
area_of_spare=4*pi*r**3/3
print(area_of_spare,'cm')
# Out:
# 904.7786842338604 cm

# %%
#10 write a program to convert the second to day,hours,minutes,second
time=float(input('enter the time in second'))
days=time//(3600*24)
time%=24*3600
hours=time//3600
time%=3600
minutes=time//60
time%=60
second=time
print("d:h:m:s->%d days :%d hours :%d minutes:%d second" % (days,hours,minutes,second))
# Out:
# enter the time in second 788657
# d:h:m:s->9 days :3 hours :4 minutes:17 second
